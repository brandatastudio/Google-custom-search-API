# %% [markdown]
# # About this document:
# this is a first contact document, here, we try for the first time, the main operations and functions that ocurr in the different files of this project. We don't fulfill any particular purpose in this document except familiarizing ourselves with the different libraries we are using. On the totality of this  project, we are going to work with
#
# Google custom search api ( basically, functions by creating custom search engines with your google dev account, and after that, calling them for particular queries in your code ).
#
# Beautifull soup ( because one of the functions tries to extract all text data of the search engines results, by scraping )
#
# To make this library work itś recommendable to download beautifull soup and  use
#
# pip install --upgrade google-api-python-client , referenced here # https://developers.google.com/api-client-library/python/apis/customsearch/v1  to make sure you are able to connect with the gogle python api.

# %% [markdown]
# # importing library

# %%
import json 
from apiclient.discovery import build
google = build('customsearch' , 'v1' , developerKey= 'AIzaSyAb4m_ROZA7k3OAkOLCKvnjsiwLiw9PTwc')

# %% [markdown]
# # Create a custom search engine

# %%
# You have to create your own search engine, specifying either the domains you want always scraped, or a list of json markup
# that specifies the type of domains you are interested, in our example, we created a custom search engine with the basic
# generic types of markup ( trying to simulate googles search results as much as possible )  on english language

# Urls you need : https://schema.org/docs/schemas.html  
# https://developers.google.com/custom-search/v1/overview
# https://cse.google.com/cse/all here is the developer console, to create the search engine

# After following those instructions, you will get an url for your search engine that can be accessed, like this one

engbasicsearch = 'https://cse.google.com/cse?cx=015037008072435013508:npqosegaj6o'


# the cx parameter = is the id of the search engine

# %%
# With this, we can now create  function that will access a string into the created search engine, and return it's
#results in a dataframe. 

def basicsearch(stringar) :
    import pandas as pd 
    csid = '015037008072435013508:npqosegaj6o'
    res = google.cse().list(q=stringar,cx = csid).execute()
    res2df = pd.DataFrame(res["items"])
    return(res2df)
    
example = basicsearch("van dos y se cae el del medio ")

example.head()
# Out:
#         cacheId                 displayLink  \
# 0  mUBZ2xiAGRsJ             www.youtube.com
# 1  qq9tB4VebcUJ  www.amazinkprintstudio.com
# 2  EWeWqaMjHW0J             www.youtube.com
# 3  V5iviXESo90J             www.lasexta.com
# 4  Q6EuH7-kaNUJ             www.youtube.com
#
#                                         formattedUrl  \
# 0        https://www.youtube.com/watch?v=YqTrs7Lq-D0
# 1  https://www.amazinkprintstudio.com/prints/vand...
# 2        https://www.youtube.com/watch?v=BuNSyMRf6AU
# 3  https://www.lasexta.com/.../dario-adanti-adapt...
# 4        https://www.youtube.com/watch?v=jNIBs02p-Ks
#
#                                     htmlFormattedUrl  \
# 0        https://www.youtube.com/watch?v=YqTrs7Lq-D0
# 1  https://www.amazinkprintstudio.com/prints/<b>v...
# 2        https://www.youtube.com/watch?v=BuNSyMRf6AU
# 3  https://www.lasexta.com/.../dario-adanti-adapt...
# 4        https://www.youtube.com/watch?v=jNIBs02p-Ks
#
# ...

# %% [markdown]
# # Using beautifull soup

# %%
linkobject = 'https://elpais.com/internacional/2019/01/23/actualidad/1548249429_996363.html'

linkobject2 = 'http://www.eluniversal.com/politica/31564/eeuu-advierte-de-respuesta-significativa-ante-cualquier-amenaza-hacia-la-oposicion'
from bs4 import BeautifulSoup
import requests
import json

r = requests.get(linkobject, headers={'User-agent' : 'Chrome'})

rtext = r.text


soup = BeautifulSoup(rtext)
# Out:
# /home/stefano/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/stefano/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
textr= soup.find_all(lambda tag: tag.name == 'p' and not tag.attrs)

textr2= soup.get_text()  # este funciona siempre  el otro no funciona si hay una estructura de texto interna definida. 

print(textr2)
# Out:
# (window.NREUM||(NREUM={})).loader_config={xpid:"VQEDUVdSCxAIVVVUBggHVw=="};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(21),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.n
# ...

# %%
#This will eliminate all the code <> in the string. 

import re
h = re.sub('<.*?>', '', str(textr2))



print(type(h))
# Out:
# <class 'str'>

# %%
h = re.sub('http.*?,' ,'', h)
print(h)
# Out:
# window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer
# ...

# %% [markdown]
# # Create a list with the sentences of the string

# %%
objectsentenceslist= re.split('[.!?]',h)

print(objectsentenceslist)
# Out:
# ['[El presidente venezolano, Nicolás Maduro, que el pasado miércoles dio tres días de plazo a los diplomáticos estadounidenses para abandonar el país, anunció este sábado una negociación de un mes de duración para el establecimiento de oficinas de intereses en ambos países', ' Este sábado, en una entrevista grabada en Caracas por la filial turca de la cadena CNN,\xa0Maduro ha expresado la actuación de Juan Guaidó, el líder de la oposición venezolana que esta semana se autoproclamó presidente interino del país, va en contra de la constitución', ' En dicha entrevista, Maduro ha cargado contra los países europeos que difundieron anuncios de apoyo a Guaidó: "Se han comportado con arrogancia', ' Nadie puede darnos un ultimátum"', ' El mensaje llega después de que el presidente del Gobierno español, Pedro Sánchez, anunciase este sábado que reconocerá al líder opositor como presidente "si en ocho días no hay una convocatoria de elecciones justas y libres"', ' Francia, Alemania y Reino Unido
# ...

# %% [markdown]
# # Put object inside text document

# %%
name_of_file = "prueba"
path = '/home/stefano/Dropbox/Aprendizaje util/Programacion learning/proyecto google search/'
completeName = path + name_of_file + ".txt"
File_object = open(file =completeName,mode = 'w')
File_object.write(h)
File_object.close()

# %%
import os

os.getcwd()
# Out:
# '/home/stefano/Dropbox/Aprendizaje util/Programacion learning/proyecto google search'
